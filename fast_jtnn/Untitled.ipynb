# %%
a = [[None, 'a'], ['a'], ['aa']]

# %%
a[1].replace('a', 'b')
# Out:
# 'b'

# %%
new = []

# %%
for i in a:
    try:
        for j in i:
            repl = j.replace('a', 'b')
            new.append(repl)
    except:
        pass

# %%
new
# Out:
# ['b', 'bb']

# %%
import pickle

# %%
with open('/home/rgur/CS6250_project/demo/tensors-0.pkl') as f:
    var = pickle.load(f)

# %%
var
# Out:
# [(<fast_jtnn.mol_tree.MolTree at 0x7f54e9edaad0>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547e9cc410>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547ec03410>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547ebc2650>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547eab26d0>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547e8b2910>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547e898e10>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547e679090>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547ec7b390>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547ec985d0>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547f82cd50>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547f839f90>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547effea50>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547e6ccc90>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547e996690>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547e996ed0>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547e9b3950>,
#   <fast_jtnn.mol_tree.MolTree at 0x7f547e950290>),
#  (<fast_jtnn.mol_tree.MolTree at 0x7f547e950b90>,
# ...
